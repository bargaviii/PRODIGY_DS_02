# %% [markdown]
# # TASK 2 PRODIGY_DS_02 BARGAVI

# %%
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv("C:\\Users\\Bargavi\\Desktop\\train.csv")

# %%
data.head(1310)
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1         0       3
# 1               2         1       1
# 2               3         1       3
# 3               4         1       1
# 4               5         0       3
# ...           ...       ...     ...
# 1304         1305         0       3
# 1305         1306         1       1
# 1306         1307         0       3
# 1307         1308         0       3
# 1308         1309         0       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of       PassengerId  Survived  Pclass  \
# 0               1         0       3
# 1               2         1       1
# 2               3         1       3
# 3               4         1       1
# 4               5         0       3
# ...           ...       ...     ...
# 1304         1305         0       3
# 1305         1306         1       1
# 1306         1307         0       3
# 1307         1308         0       3
# 1308         1309         0       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     1309 non-null   int64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1307 non-null   object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 122.8+ KB

# %% [markdown]
# #### we will check for empty values in the dataset(given below):

# %%
data.isnull().sum()
# Out:
# PassengerId       0
# Survived          0
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# dtype: int64

# %%
data.drop(columns= "Cabin",axis=1,inplace=True)

# %% [markdown]
# #### In the above we have dropped the column "Cabin" as it is wasnt useful to as and also mostly contained null values

# %%
data['Age'].fillna(data['Age'].mean(),inplace=True)
# Out:
# C:\Users\Bargavi\AppData\Local\Temp\ipykernel_17064\2853692610.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Age'].fillna(data['Age'].mean(),inplace=True)

# %%
data['Embarked'].fillna(df['Embarked'].mode()[0],inplace=True)
# Out:
# C:\Users\Bargavi\AppData\Local\Temp\ipykernel_17064\3313622572.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Embarked'].fillna(df['Embarked'].mode()[0],inplace=True)

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### no duplicate vaues are present and all missing values are filled

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("C:\\Users\\Bargavi\\Desktop\\train.csv")  # Adjust the path if needed

# Calculate survival counts by gender
survival_by_gender = df.groupby('Sex')['Survived'].mean()

plt.figure(figsize=(6, 6))
plt.pie(
    survival_by_gender,
    labels=survival_by_gender.index,
    autopct='%1.1f%%',
    startangle=140,
    colors=['skyblue', 'lightcoral']
)

plt.title('Survival Rate by Gender')
plt.axis('equal')  # Make it a circle
plt.show()

# %% [markdown]
# #### (The above pie chart shows the survival rate by gender)

# %%
sns.countplot(x='Survived',data=df,palette='magma',)
plt.xlabel("Survival status")
plt.ylabel("Number of people")
plt.xticks(ticks=[0,1],labels=['Not survived','survived'])
plt.show()
# Out:
# C:\Users\Bargavi\AppData\Local\Temp\ipykernel_17064\3441046057.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Survived',data=df,palette='magma',)

# %% [markdown]
# #### (The above bar chart shows the survival of people)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = df.dropna(subset=['Age'])

bins = [0, 10, 20, 30, 40, 50, 60, 80]
labels = ['0–10', '11–20', '21–30', '31–40', '41–50', '51–60', '61+']
df['AgeGroup'] = pd.cut(df['Age'], bins=bins, labels=labels, right=False)

# Calculate survival rate by age group
age_survival = df.groupby('AgeGroup')['Survived'].mean().reset_index()

# Plot bar chart
plt.figure(figsize=(8, 5))
sns.barplot(x='AgeGroup', y='Survived', data=age_survival, palette='inferno')

plt.title('Survival Rate by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Survival Rate')
plt.ylim(0, 1)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Bargavi\AppData\Local\Temp\ipykernel_17064\73373148.py:12: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_survival = df.groupby('AgeGroup')['Survived'].mean().reset_index()
# C:\Users\Bargavi\AppData\Local\Temp\ipykernel_17064\73373148.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='AgeGroup', y='Survived', data=age_survival, palette='inferno')

# %% [markdown]
# #### (The above bar chart shows survival rate of each age groups)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Drop missing fare values
df = df.dropna(subset=['Fare'])

# Create fare bins (quartiles)
df['FareRange'] = pd.qcut(df['Fare'], 4, labels=['Low', 'Medium', 'High', 'Very High'])

# Group by FareRange and calculate survival rate
fare_survival = df.groupby('FareRange')['Survived'].mean().reset_index()

# Plot survival rate by fare range
plt.figure(figsize=(8, 5))
sns.barplot(x='FareRange', y='Survived', data=fare_survival, palette='flare')

# Customize the plot
plt.title('Survival Rate by Fare Range')
plt.xlabel('Fare Category')
plt.ylabel('Survival Rate')
plt.ylim(0, 1)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Bargavi\AppData\Local\Temp\ipykernel_17064\2887020766.py:12: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   fare_survival = df.groupby('FareRange')['Survived'].mean().reset_index()
# C:\Users\Bargavi\AppData\Local\Temp\ipykernel_17064\2887020766.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='FareRange', y='Survived', data=fare_survival, palette='flare')

# %% [markdown]
# #### (The abov bar plot shows the survival rate by fare change)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Set style
sns.set(style="whitegrid")

# Group data by gender and class, and calculate survival rate
grouped = df.groupby(['Sex', 'Pclass'])['Survived'].mean().reset_index()

# Plot grouped bar chart
plt.figure(figsize=(8, 5))
sns.barplot(x='Pclass', y='Survived', hue='Sex', data=grouped, palette='icefire')

# Customize plot
plt.title('Survival Rate by Gender and Passenger Class')
plt.xlabel('Passenger Class (1 = 1st, 2 = 2nd, 3 = 3rd)')
plt.ylabel('Survival Rate')
plt.ylim(0, 1)
plt.legend(title='Gender')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### (The above bar chart shows the survival rate by gender and passenger class)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Drop rows with missing 'Embarked' values
df = df.dropna(subset=['Embarked'])

# Group by embarkation point and calculate survival rate
embark_survival = df.groupby('Embarked')['Survived'].mean().reset_index()

# Plot bar chart
plt.figure(figsize=(6, 4))
sns.barplot(x='Embarked', y='Survived', data=embark_survival, palette='rocket')

# Customize chart
plt.title('Survival Rate by Embarkation Point')
plt.xlabel('Embarkation Point (C = Cherbourg, Q = Queenstown, S = Southampton)')
plt.ylabel('Survival Rate')
plt.ylim(0, 1)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Bargavi\AppData\Local\Temp\ipykernel_17064\1398203871.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Embarked', y='Survived', data=embark_survival, palette='rocket')

# %% [markdown]
# #### (The above bar chart shows survival rate by embarkation point)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate family size
df['FamilySize'] = df['SibSp'] + df['Parch'] + 1

# Group by family size and calculate survival rate
family_survival = df.groupby('FamilySize')['Survived'].mean().reset_index()

# Plot survival rate vs family size
plt.figure(figsize=(8, 5))
sns.barplot(x='FamilySize', y='Survived', data=family_survival, palette='viridis')

# Customize the plot
plt.title('Survival Rate by Family Size')
plt.xlabel('Family Size (Siblings/Spouses + Parents/Children + Self)')
plt.ylabel('Survival Rate')
plt.ylim(0, 1)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Bargavi\AppData\Local\Temp\ipykernel_17064\161000675.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='FamilySize', y='Survived', data=family_survival, palette='viridis')

# %% [markdown]
# #### (The above bar chart shows survival rate by family size)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv("C:\\Users\\Bargavi\\Desktop\\train.csv")

# Create a 'FamilySize' column
df['FamilySize'] = df['SibSp'] + df['Parch']

# Create 'Alone' column: 1 if alone, 0 if with family
df['Alone'] = df['FamilySize'].apply(lambda x: 'Alone' if x == 0 else 'With Family')

# Set seaborn style
sns.set(style="whitegrid")

# Plot survival counts based on Alone status
plt.figure(figsize=(7, 5))
sns.countplot(data=df, x='Alone', hue='Survived', palette='pastel')

# Customize the plot
plt.title('Survival Count: Alone vs With Family')
plt.xlabel('Passenger Status')
plt.ylabel('Number of Passengers')
plt.legend(title='Survived', labels=['No', 'Yes'])
plt.tight_layout()
plt.show()

# %% [markdown]
# #### (The above bar chart shows the survivors and non survivors side by side for passengers who were alone and with families)

# %% [markdown]
# ### OBSERVATIONS FROM THE ANALYSIS ARE AS FOLLOWS:
#
# #### • More people did not survive than those who survived
# #### • The overall survival rate is less than 50%.
# #### • Females had a much higher survival rate than males
# #### • 86.5% of survivors being female and only 13.5% being male.
# #### • Passengers who paid a very high fare had the highest survival rate, exceeding 60%.
# #### • Those who paid a low fare had the lowest survival rate, around 23%.
# #### • Female passengers in first and second class had survival rates close to 100%.
# #### • Male passengers had low survival rates across all classes, especially in third class where it was about 10%.
# #### • Passengers who boarded from Cherbourg had the highest survival rate at around 53%.
# #### • Passengers from Southampton had the lowest survival rate at approximately 35%.
# #### • Passengers with a family size of four had the highest survival rate at about 77%.
# #### • Passengers with a family size of one or more than six had much lower survival rates.
# #### • Passengers who were with family had a higher number of survivors compared to those who were alone.
# #### • Passengers who were alone had a significantly higher number of non-survivors, with fewer survivors compared to those with family.
# #### • Children aged 0–10 had the highest survival rate among all age groups, at approximately 57%.
# #### • The lowest survival rates were seen in the 21–30 and 61+ age groups, around 33% and 32% respectively.
